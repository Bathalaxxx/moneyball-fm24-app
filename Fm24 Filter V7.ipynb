# %%
# !pip install xlsxwriter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xlsxwriter in c:\users\testing rename nalng\appdata\roaming\python\python312\site-packages (3.2.3)

# %%
# !pip install html5lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: html5lib in c:\users\testing rename nalng\appdata\roaming\python\python312\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\programdata\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from html5lib) (0.5.1)

# %%
import pandas as pd
import numpy as np
import os
from io import BytesIO
import warnings
warnings.filterwarnings("ignore", "This pattern is interpreted as a regular expression")

# ================================
# CONFIGURATION
# ================================
SIGNED_HTML_PATH = r'C:/Users/Testing Rename nalng/Documents/Sports Interactive/Football Manager 2024/Stuttgart Signings Available S1 Winter.html' #Transfers
LOANS_HTML_PATH = r'C:/Users/Testing Rename nalng/Documents/Sports Interactive/Football Manager 2024/Stuttgart Loans Available S1 Winter.html' #Loans
UNIVERSAL_HTML_PATH = r'C:/Users/Testing Rename nalng/Documents/Sports Interactive/Football Manager 2024/Stuttgart Universe S1 Winter.html'
OUTPUT_PATH = r'C:/Users/Testing Rename nalng/Desktop/Stuttgart_Season_1_Winter_FB_Fix.xlsx'
LEAGUE_MULTIPLIERS_PATH = r'C:/Users/Testing Rename nalng/Desktop/League Multipliers.xlsx'  # Path to your Excel file

TEXT_COLUMNS = [
    'UID', 'Name', 'Rec', 'EU National', 'Position', 'Pros',
    'Preferred Foot', 'Inf', 'Transfer Value', 'Nat', 'Division', 'Club', 'Personality'
]

PERCENTAGE_COLUMNS = ['Sv %', 'OP-Cr %', 'Hdr %', 'Conv %', 'Pas %', 'Cr C/A', 'Tck R', 'Pens Saved Ratio', 'Pen/R', 'Shot %']

# ================================
# LOAD LEAGUE POWER RATINGS FROM EXCEL
# ================================
def load_league_power(file_path):
    try:
        # Read the Excel file
        df = pd.read_excel(file_path)
        
        # Convert to dictionary with 'League' as key and 'Power Rating' as value
        league_power = dict(zip(df['League'], df['Power Rating']))
        
        # Add default 'Others' value if not present in the file
        if 'Others' not in league_power:
            league_power['Others'] = 5
            
        return league_power
    except Exception as e:
        print(f"Error loading league power ratings: {e}")
        # Return a default dictionary if file can't be loaded
        return {'Others': 5}

# Load the league power ratings
LEAGUE_POWER = load_league_power(LEAGUE_MULTIPLIERS_PATH)

# ================================
# LEAGUE NAME FIXES FOR ENCODING ISSUES
# ================================
LEAGUE_NAME_FIXES = {
    'BrasileirÃ£o AssaÃ­ SÃ©rie A': 'Brasileirão Assaí Série A',
    'Primera FederaciÃ³n Grupo I': 'Primera Federación Grupo I',
    'Liga Profesional de FÃºtbol': 'Liga Profesional de Fútbol',
    'Primera FederaciÃ³n Grupo I': 'Primera Federación Grupo',
    'Primera FederaciÃ³n Grupo III': 'Primera Federación Grupo',
    'Primera FederaciÃ³n Grupo IV': 'Primera Federación Grupo',
    'Primera FederaciÃ³n Grupo V': 'Primera Federación Grupo',
    'Primera FederaciÃ³n Grupo VI': 'Primera Federación Grupo',
    'Primera FederaciÃ³n Grupo VII': 'Primera Federación Grupo',
    'Regionalliga SÃ¼dwest': 'Regionalliga Südwest',
    'Serie C NOW Girone A': 'Serie C NOW',
    'Serie C NOW Girone B': 'Serie C NOW',
    'Serie C NOW Girone C': 'Serie C NOW',
    'Spor Toto SÃ¼per Lig': 'Spor Toto Süper Lig',
    'French National 3 - Group A': 'French National 3',
    'French National 3 - Group B': 'French National 3',
    'French National 3 - Group C': 'French National 3',
    'French National 3 - Group D': 'French National 3',
    'French National 3 - Group E': 'French National 3',
    'French National 3 - Group F': 'French National 3',
    'French National 3 - Group G': 'French National 3',
    'French National 3 - Group H': 'French National 3',
    'French National 3 - Group I': 'French National 3',
    'French National 3 - Group J': 'French National 3',
    'French National 3 - Group K': 'French National 3',
    'French National 3 - Group L': 'French National 3',
    'BrasileirÃ£o Serie B Chevrolet': 'Brasileirão Serie B Chevrolet',
    'Serie D Girone A': 'Serie D',
    'Serie D Girone B': 'Serie D',
    'Serie D Girone C': 'Serie D',
    'Serie D Girone D': 'Serie D',
    'Serie D Girone E': 'Serie D',
    'Serie D Girone F': 'Serie D',
    'Serie D Girone G': 'Serie D',
    'Serie D Girone H': 'Serie D',
    'Serie D Girone I': 'Serie D',
    'Serie D Girone J': 'Serie D',
    'Serie D Girone K': 'Serie D',
    'Regionalliga West': 'Regionalliga',
    'Regionalliga Nord': 'Regionalliga',
    'Regionalliga Südwest': 'Regionalliga',
    'Regionalliga Bayern': 'Regionalliga',
    'Regionalliga Nordost': 'Regionalliga',
    'Russian Second Division A Gold': 'Russian Second Division A',
    'Russian Second Division A Silver': 'Russian Second Division A',  
    'Russian Second Division A Bronze': 'Russian Second Division A',    
    'Russian Second Division B - Group 1': 'Russian Second Division B',
    'Russian Second Division B - Group 2': 'Russian Second Division B',
    'Russian Second Division B - Group 3': 'Russian Second Division B',
    'DR Congo Premier Division A': 'DR Congolese Premier Division',
    'DR Congo Premier Division B': 'DR Congolese Premier Division',

    # Add more fixes as needed
}

def fix_league_names(df):
    """Fix encoding issues in league names in the DataFrame"""
    if 'Division' in df.columns:
        df['Division'] = df['Division'].replace(LEAGUE_NAME_FIXES)
    return df

# ================================
# LOAD HTML FILES
# ================================
if not os.path.exists(SIGNED_HTML_PATH):
    raise FileNotFoundError(f"Signed players HTML not found: {SIGNED_HTML_PATH}")

if not os.path.exists(UNIVERSAL_HTML_PATH):
    raise FileNotFoundError(f"Universal players HTML not found: {UNIVERSAL_HTML_PATH}")

if not os.path.exists(LOANS_HTML_PATH):
    raise FileNotFoundError(f"Loan players HTML not found: {LOANS_HTML_PATH}")

with open(SIGNED_HTML_PATH, 'r', encoding='utf-8') as file:
    signed_tables = pd.read_html(file)
df_signed = signed_tables[0].copy()
df_signed = fix_league_names(df_signed)

with open(UNIVERSAL_HTML_PATH, 'r', encoding='utf-8') as file:
    universal_tables = pd.read_html(file)
df_universal = universal_tables[0].copy()
df_universal = fix_league_names(df_universal)

with open(LOANS_HTML_PATH, 'r', encoding='utf-8') as file:
    loans_tables = pd.read_html(file)
df_loans = loans_tables[0].copy()
df_loans = fix_league_names(df_loans)

# %%
# ================================
# UID‑BASED MERGE AND LABEL  ✅ Fixed version
# ================================

def normalize_uid(df):
    df = df.copy()
    # Convert to float → Int64 (nullable integer) → string
    df['UID'] = pd.to_numeric(df['UID'], errors='coerce')  # force numeric, NaNs stay if bad
    df['UID'] = df['UID'].astype('Int64')                  # keep NaNs clean
    df['UID'] = df['UID'].astype(str).str.strip()          # final string
    return df

# 1️⃣ Normalize UIDs
df_signed    = normalize_uid(df_signed)
df_universal = normalize_uid(df_universal)
df_loans = normalize_uid(df_loans)

# 2️⃣ Add the signability flags
df_signed['Signability']    = 'Available for Transfer'
df_universal['Signability'] = 'Not Transferrable'
df_loans['Signability'] = 'Available on Loan'


# 3️⃣ Concatenate signables first, drop duplicate UIDs

df = (
    pd.concat([df_signed, df_loans, df_universal], ignore_index=True)
      .drop_duplicates(subset='UID', keep='first')
      .reset_index(drop=True)
)

# ================================
# CLEANING & CONVERSION
# ================================
def clean_and_convert_data(df):
    def convert_percentage_to_float(df, column):
        if column in df.columns:
            df[column] = (df[column].astype(str)
                          .str.replace('%', '')
                          .replace('-', np.nan)
                          .astype(float))
        return df

    # Convert minutes
    if 'Mins' in df.columns:
        df['Mins'] = pd.to_numeric(df['Mins'], errors='coerce')
        df = df[df['Mins'] >= 900].copy()

    # Convert percentage stats
    for col in PERCENTAGE_COLUMNS:
        df = convert_percentage_to_float(df, col)

    # Handle 'Dist/90' - e.g., "7.3mi"
    if 'Dist/90' in df.columns:
        df['Dist/90'] = (
            df['Dist/90']
            .astype(str)
            .str.extract(r'([\d.]+)')[0]
        )

        # Drop only if the string was completely missing
        df['Dist/90'] = pd.to_numeric(df['Dist/90'], errors='coerce')

    print("Dist/90 (after cleaning):")
    print(df['Dist/90'].describe())
    print(df['Dist/90'].dropna().head(10))






    

    # Convert all other numerical columns (except text & signability)
    for col in df.columns:
        if col not in TEXT_COLUMNS + ['Signability']:
            df[col] = pd.to_numeric(df[col], errors='coerce')

    # Handle 'Dist/90' - e.g., "7.3mi"
    if 'Dist/90' in df.columns:
        df['Dist/90'] = (
            df['Dist/90']
            .astype(str)
            .str.extract(r'([\d.]+)')[0]
        )

        # Drop only if the string was completely missing
        df['Dist/90'] = pd.to_numeric(df['Dist/90'], errors='coerce')

    print("Dist/90 (after cleaning):")
    print(df['Dist/90'].describe())
    print(df['Dist/90'].dropna().head(10))


    # Add league strength multiplier
    def get_league_multiplier(division):
        return LEAGUE_POWER.get(division, LEAGUE_POWER['Others']) / 100.0

    df['League Multiplier'] = df['Division'].apply(get_league_multiplier)
    return df

# ✅ Apply cleaning
df = clean_and_convert_data(df)

# ================================
# CONVERT RAW STATS TO PER 90
# ================================
RAW_STATS_TO_PER90 = {
    "Yel": "Yellow/90",
    "Red": "Red/90",
    "Fls": "FoulsMade/90",
    "FA": "FoulsAgainst/90",
    "Off": "Offsides/90",
    "Gl Mst": "Gl Mst/90",
    "Goals Outside Box": "Goals Outside Box/90",
    "FK Shots": "FKShots/90"
}

for raw_stat, per90_stat in RAW_STATS_TO_PER90.items():
    if raw_stat in df.columns:
        df[raw_stat] = pd.to_numeric(df[raw_stat], errors='coerce')
        df['Mins'] = pd.to_numeric(df['Mins'], errors='coerce')
        df[per90_stat] = (df[raw_stat] / (df['Mins'] / 90)).fillna(0)
    else:
        print(f"Warning: Raw stat '{raw_stat}' not found in DataFrame")

print(df['Dist/90'].dropna().unique()[:50])
print(df['Dist/90'].dtype)
# Out:
# Dist/90 (after cleaning):
# count    19558.000000
# mean         3.943604
# std          3.456740
# min          0.000000
# 25%          0.000000
# 50%          5.100000
# 75%          7.300000
# max          9.100000
# Name: Dist/90, dtype: float64
# 0    4.0
# 1    0.0
# 2    3.6
# 3    0.0
# 4    3.5
# 5    3.2
# 6    0.0
# 7    3.7
# 8    0.0
# 9    1.0
# Name: Dist/90, dtype: float64
# Dist/90 (after cleaning):
# count    19558.000000
# mean         3.943604
# std          3.456740
# min          0.000000
# 25%          0.000000
# 50%          5.100000
# 75%          7.300000
# max          9.100000
# Name: Dist/90, dtype: float64
# 0    4.0
# 1    0.0
# 2    3.6
# 3    0.0
# 4    3.5
# 5    3.2
# 6    0.0
# 7    3.7
# 8    0.0
# 9    1.0
# Name: Dist/90, dtype: float64
# [4.  0.  3.6 3.5 3.2 3.7 1.  0.4 3.  2.6 2.5 3.4 3.3 3.9 2.2 1.9 0.8 0.7
#  2.7 2.3 0.3 2.8 3.1 3.8 1.1 0.5 2.9 1.3 1.2 1.7 4.5 4.1 1.5 0.1 0.9 2.
#  0.6 2.4 4.3 5.9 1.8 1.6 0.2 2.1 7.5 6.  4.2 1.4 6.7 7.9]
# float64

# %%
df["Expires"] = df["Expires"].astype("string")
print(df["Expires"].dtype)
# Out:
# string

# %%
# Show overall info
print("==== DataFrame Info ====")
print(df.info())

print("\n==== Column Summary ====")
for col in df.columns:
    print(f"\n📌 Column: {col}")
    print(f"Type: {df[col].dtype}")
    print(f"Missing: {df[col].isna().sum()} / {len(df)}")
    
    if df[col].dtype == 'object':
        unique_vals = df[col].dropna().unique()
        print(f"Unique Values: {len(unique_vals)}")
        print("Sample:", unique_vals[:10])
    
    elif pd.api.types.is_numeric_dtype(df[col]):
        print(df[col].describe())

    else:
        print("Sample:", df[col].dropna().head(5).tolist())
# Out:
# ==== DataFrame Info ====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19558 entries, 0 to 19557
# Data columns (total 88 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EU National           19558 non-null  object
#  1   Name                  19558 non-null  object
#  2   UID                   19558 non-null  object
#  3   Mins                  19558 non-null  int64
#  4   Position              19558 non-null  object
#  5   Shot %                17407 non-null  float64
#  6   Personality           1034 non-null   object
#  7   Age                   19558 non-null  int64
#  8   Preferred Foot        19558 non-null  object
#  9   Rec                   19558 non-null  object
#  10  Club                  19558 non-null  object
#  11  Transfer Value        19558 non-null  object
#  12  Sv %                  2049 non-null   float64
#  13  OP-Cr %               11018 non-null  float64
#  14  Off                   19558 non-null  int64
#  15  Hdr %                 11760 non-null  float64
#  16  Distance              0 non-null      float64
#  17  Cr C/A                8352 non-null   float64
#  18  Conv %                11460 non-null  float64
#  19  Saves/90              1121 non-null   float64
#  20  Clr/90                19558 non-null  float64
#  21  FA                    19558 non-null  int64
#  22  Tck/90                18336 non-null  float64
#  23  Shot/90               17407 non-null  float64
#  24  xGP                   2049 non-null   float64
#  25  ShT/90                17407 non-null  float64
#  26  Shots Outside Box/90  17509 non-null  float64
#  27  Shts Blckd/90         17509 non-null  float64
#  28  Pr passes/90          19558 non-null  float64
#  29  Pres C/90             19558 non-null  float64
#  30  Pres A/90             19558 non-null  float64
#  31  Poss Won/90           19558 non-null  float64
#  32  Poss Lost/90          19558 non-null  float64
#  33  Ps C/90               19558 non-null  float64
#  34  Ps A/90               19558 non-null  float64
#  35  OP-KP/90              19558 non-null  float64
#  36  OP-Crs C/90           17509 non-null  float64
#  37  OP-Crs A/90           17509 non-null  float64
#  38  NP-xG/90              19558 non-null  float64
#  39  Gl Mst                19558 non-null  int64
#  40  K Tck/90              19558 non-null  float64
#  41  K Ps/90               11624 non-null  float64
#  42  K Hdrs/90             19558 non-null  float64
#  43  Int/90                11589 non-null  float64
#  44  Sprints/90            19558 non-null  float64
#  45  Hdrs W/90             11760 non-null  float64
#  46  Gls/90                11460 non-null  float64
#  47  All/90                2049 non-null   float64
#  48  xA/90                 19558 non-null  float64
#  49  xG/90                 19558 non-null  float64
#  50  xGP/90                2049 non-null   float64
#  51  Drb/90                10635 non-null  float64
#  52  Dist/90               19558 non-null  float64
#  53  Cr C/90               17509 non-null  float64
#  54  Cln/90                2049 non-null   float64
#  55  Ch C/90               9188 non-null   float64
#  56  Cons                  0 non-null      float64
#  57  Pas A                 19558 non-null  int64
#  58  Inf                   8965 non-null   object
#  59  Pas %                 19558 non-null  float64
#  60  Blk/90                10791 non-null  float64
#  61  Aer A/90              11760 non-null  float64
#  62  Asts/90               13214 non-null  float64
#  63  Crs A/90              17509 non-null  float64
#  64  Hdrs L/90             11695 non-null  float64
#  65  Division              19558 non-null  object
#  66  Nat                   19558 non-null  object
#  67  Fls                   19558 non-null  int64
#  68  xG/shot               19558 non-null  float64
#  69  FK Shots              17509 non-null  float64
#  70  Goals Outside Box     17509 non-null  float64
#  71  Tck R                 18336 non-null  float64
#  72  xG-OP                 19558 non-null  float64
#  73  Pens Saved Ratio      827 non-null    float64
#  74  Pen/R                 891 non-null    float64
#  75  Yel                   19558 non-null  int64
#  76  Red                   19558 non-null  int64
#  77  Expires               0 non-null      string
#  78  Signability           19558 non-null  object
#  79  League Multiplier     19558 non-null  float64
#  80  Yellow/90             19558 non-null  float64
#  81  Red/90                19558 non-null  float64
#  82  FoulsMade/90          19558 non-null  float64
#  83  FoulsAgainst/90       19558 non-null  float64
#  84  Offsides/90           19558 non-null  float64
#  85  Gl Mst/90             19558 non-null  float64
#  86  Goals Outside Box/90  19558 non-null  float64
#  87  FKShots/90            19558 non-null  float64
# dtypes: float64(65), int64(9), object(13), string(1)
# memory usage: 13.1+ MB
# None
#
# ==== Column Summary ====
#
# 📌 Column: EU National
# Type: object
# Missing: 0 / 19558
# Unique Values: 2
# Sample: ['Yes' 'No']
#
# 📌 Column: Name
# Type: object
# Missing: 0 / 19558
# Unique Values: 19081
# Sample: ['Illan Meslier' 'Omri Glazer' 'Filip StankoviÄ\x87' 'Mihai Popa'
#  'Robby McCrorie' 'Evan Anderson' 'Lucho GarcÃ\xada' 'Marcel Lotka'
#  'Teddy Boulhendi' 'Ladislav Herda']
#
# 📌 Column: UID
# Type: object
# Missing: 0 / 19558
# Unique Values: 19558
# Sample: ['49040115' '42058059' '43425978' '57177195' '61060675' '2000198607'
#  '67232107' '96116939' '49043814' '2002125129']
#
# 📌 Column: Mins
# Type: int64
# Missing: 0 / 19558
# count    19558.000000
# mean      1643.278761
# std        529.556521
# min       1000.000000
# 25%       1270.000000
# 50%       1564.000000
# 75%       1808.000000
# max       5777.000000
# Name: Mins, dtype: float64
#
# 📌 Column: Position
# Type: object
# Missing: 0 / 19558
# Unique Values: 516
# Sample: ['GK' 'D (RC), DM' 'ST (C)' 'D (C), DM' 'D/WB (L)' 'D/WB (R)' 'D (RC)'
#  'M (R), AM (RL), ST (C)' 'D/WB/AM (L)' 'D (LC), WB (L), DM']
#
# 📌 Column: Shot %
# Type: float64
# Missing: 2151 / 19558
# count    17407.000000
# mean        29.325214
# std         17.853413
# min          0.000000
# 25%         17.000000
# 50%         30.000000
# 75%         42.000000
# max        100.000000
# Name: Shot %, dtype: float64
#
# 📌 Column: Personality
# Type: object
# Missing: 18524 / 19558
# Unique Values: 26
# Sample: ['Fairly Ambitious' 'Fairly Determined' 'Perfectionist' 'Balanced'
#  'Spirited' 'Fairly Professional' 'Ambitious' 'Driven' 'Fairly Sporting'
#  'Temperamental']
#
# 📌 Column: Age
# Type: int64
# Missing: 0 / 19558
# count    19558.000000
# mean        26.096022
# std          4.057959
# min         16.000000
# 25%         24.000000
# 50%         26.000000
# 75%         29.000000
# max         39.000000
# Name: Age, dtype: float64
#
# 📌 Column: Preferred Foot
# Type: object
# Missing: 0 / 19558
# Unique Values: 6
# Sample: ['Left Only' 'Right' 'Unknown' 'Right Only' 'Left' 'Either']
#
# 📌 Column: Rec
# Type: object
# Missing: 0 / 19558
# Unique Values: 1
# Sample: ['- - -']
#
# 📌 Column: Club
# Type: object
# Missing: 0 / 19558
# Unique Values: 4078
# Sample: ['Leeds Utd' 'Al-Faisaly (KSA)' 'Como' 'FCSB' 'Rangers' 'Arbroath'
#  'AtlÃ©tico Huila' 'Burnley' 'ASO Chlef' 'Slavia Prague']
#
# 📌 Column: Transfer Value
# Type: object
# Missing: 0 / 19558
# Unique Values: 1325
# Sample: ['Not for Sale' '$35K - $350K' '$7M - $11M' '$80K - $800K' 'Unknown'
#  '$9K - $90K' '$425K - $4.2M' '$110K - $1.1M' '$120K - $375K'
#  '$275K - $2.7M']
#
# 📌 Column: Sv %
# Type: float64
# Missing: 17509 / 19558
# count    2049.000000
# mean       38.550512
# std        35.614356
# min         0.000000
# 25%         0.000000
# 50%        60.000000
# 75%        71.000000
# max       100.000000
# Name: Sv %, dtype: float64
#
# 📌 Column: OP-Cr %
# Type: float64
# Missing: 8540 / 19558
# count    11018.000000
# mean        15.311218
# std         15.410612
# min          0.000000
# 25%          6.000000
# 50%         13.000000
# 75%         20.000000
# max        100.000000
# Name: OP-Cr %, dtype: float64
#
# 📌 Column: Off
# Type: int64
# Missing: 0 / 19558
# count    19558.000000
# mean         1.547397
# std          3.127790
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          2.000000
# max         36.000000
# Name: Off, dtype: float64
#
# 📌 Column: Hdr %
# Type: float64
# Missing: 7798 / 19558
# count    11760.000000
# mean        44.139201
# std         20.916848
# min          0.000000
# 25%         26.000000
# 50%         44.000000
# 75%         62.000000
# max        100.000000
# Name: Hdr %, dtype: float64
#
# 📌 Column: Distance
# Type: float64
# Missing: 19558 / 19558
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Distance, dtype: float64
#
# 📌 Column: Cr C/A
# Type: float64
# Missing: 11206 / 19558
# count    8352.000000
# mean       20.236470
# std        15.364793
# min         1.000000
# 25%        11.000000
# 50%        16.000000
# 75%        24.000000
# max       100.000000
# Name: Cr C/A, dtype: float64
#
# 📌 Column: Conv %
# Type: float64
# Missing: 8098 / 19558
# count    11460.000000
# mean        14.683508
# std         12.532834
# min          1.000000
# 25%          7.000000
# 50%         12.000000
# 75%         18.000000
# max        100.000000
# Name: Conv %, dtype: float64
#
# 📌 Column: Saves/90
# Type: float64
# Missing: 18437 / 19558
# count    1121.000000
# mean        2.036574
# std         1.091158
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         7.000000
# Name: Saves/90, dtype: float64
#
# 📌 Column: Clr/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.958909
# std          1.679536
# min          0.000000
# 25%          0.000000
# 50%          0.580000
# 75%          1.200000
# max         11.080000
# Name: Clr/90, dtype: float64
#
# 📌 Column: FA
# Type: int64
# Missing: 0 / 19558
# count    19558.000000
# mean        16.719603
# std         12.840461
# min          0.000000
# 25%          8.000000
# 50%         14.000000
# 75%         22.000000
# max        147.000000
# Name: FA, dtype: float64
#
# 📌 Column: Tck/90
# Type: float64
# Missing: 1222 / 19558
# count    18336.000000
# mean         1.482507
# std          0.653080
# min          0.000000
# 25%          1.010000
# 50%          1.500000
# 75%          1.910000
# max          4.800000
# Name: Tck/90, dtype: float64
#
# 📌 Column: Shot/90
# Type: float64
# Missing: 2151 / 19558
# count    17407.000000
# mean         1.211665
# std          0.958693
# min          0.040000
# 25%          0.430000
# 50%          0.890000
# 75%          1.860000
# max          6.650000
# Name: Shot/90, dtype: float64
#
# 📌 Column: xGP
# Type: float64
# Missing: 17509 / 19558
# count    2049.000000
# mean        0.776813
# std         3.649278
# min       -17.510000
# 25%         0.000000
# 50%         0.000000
# 75%         1.630000
# max        24.450000
# Name: xGP, dtype: float64
#
# 📌 Column: ShT/90
# Type: float64
# Missing: 2151 / 19558
# count    17407.000000
# mean         0.431981
# std          0.476198
# min          0.000000
# 25%          0.080000
# 50%          0.240000
# 75%          0.650000
# max          3.360000
# Name: ShT/90, dtype: float64
#
# 📌 Column: Shots Outside Box/90
# Type: float64
# Missing: 2049 / 19558
# count    17509.000000
# mean         0.199481
# std          0.278132
# min          0.000000
# 25%          0.000000
# 50%          0.080000
# 75%          0.300000
# max          2.260000
# Name: Shots Outside Box/90, dtype: float64
#
# 📌 Column: Shts Blckd/90
# Type: float64
# Missing: 2049 / 19558
# count    17509.000000
# mean         0.178354
# std          0.359113
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.170000
# max          3.770000
# Name: Shts Blckd/90, dtype: float64
#
# 📌 Column: Pr passes/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         1.737778
# std          1.940663
# min          0.000000
# 25%          0.000000
# 50%          0.690000
# 75%          3.480000
# max         10.190000
# Name: Pr passes/90, dtype: float64
#
# 📌 Column: Pres C/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         1.084642
# std          1.150189
# min          0.000000
# 25%          0.000000
# 50%          0.850000
# 75%          2.090000
# max          4.650000
# Name: Pres C/90, dtype: float64
#
# 📌 Column: Pres A/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         3.974578
# std          4.249589
# min          0.000000
# 25%          0.000000
# 50%          2.720000
# 75%          7.950000
# max         16.110000
# Name: Pres A/90, dtype: float64
#
# 📌 Column: Poss Won/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         5.483546
# std          6.385080
# min          0.000000
# 25%          0.000000
# 50%          2.520000
# 75%         10.930000
# max         37.620000
# Name: Poss Won/90, dtype: float64
#
# 📌 Column: Poss Lost/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         6.679180
# std          7.122963
# min          0.000000
# 25%          0.000000
# 50%          3.970000
# 75%         12.950000
# max         40.480000
# Name: Poss Lost/90, dtype: float64
#
# 📌 Column: Ps C/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean        24.948051
# std         13.067408
# min          6.310000
# 25%         13.740000
# 50%         19.150000
# 75%         38.130000
# max         73.440000
# Name: Ps C/90, dtype: float64
#
# 📌 Column: Ps A/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean        31.520236
# std         12.829126
# min         15.010000
# 25%         20.360000
# 50%         23.900000
# 75%         44.600000
# max         77.720000
# Name: Ps A/90, dtype: float64
#
# 📌 Column: OP-KP/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.477479
# std          0.556209
# min          0.000000
# 25%          0.000000
# 50%          0.220000
# 75%          0.910000
# max          4.130000
# Name: OP-KP/90, dtype: float64
#
# 📌 Column: OP-Crs C/90
# Type: float64
# Missing: 2049 / 19558
# count    17509.000000
# mean         0.153747
# std          0.262569
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.190000
# max          2.690000
# Name: OP-Crs C/90, dtype: float64
#
# 📌 Column: OP-Crs A/90
# Type: float64
# Missing: 2049 / 19558
# count    17509.000000
# mean         1.001245
# std          1.563089
# min          0.000000
# 25%          0.000000
# 50%          0.240000
# 75%          1.100000
# max          9.680000
# Name: OP-Crs A/90, dtype: float64
#
# 📌 Column: NP-xG/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.121292
# std          0.116267
# min          0.000000
# 25%          0.030000
# 50%          0.080000
# 75%          0.190000
# max          0.950000
# Name: NP-xG/90, dtype: float64
#
# 📌 Column: Gl Mst
# Type: int64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.039677
# std          0.226488
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          4.000000
# Name: Gl Mst, dtype: float64
#
# 📌 Column: K Tck/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.050474
# std          0.093795
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.070000
# max          1.050000
# Name: K Tck/90, dtype: float64
#
# 📌 Column: K Ps/90
# Type: float64
# Missing: 7934 / 19558
# count    11624.000000
# mean         0.863359
# std          0.583664
# min          0.020000
# 25%          0.360000
# 50%          0.820000
# 75%          1.250000
# max          4.640000
# Name: K Ps/90, dtype: float64
#
# 📌 Column: K Hdrs/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.168526
# std          0.302442
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.190000
# max          1.800000
# Name: K Hdrs/90, dtype: float64
#
# 📌 Column: Int/90
# Type: float64
# Missing: 7969 / 19558
# count    11589.000000
# mean         1.364060
# std          0.666566
# min          0.020000
# 25%          0.950000
# 50%          1.400000
# 75%          1.800000
# max          4.350000
# Name: Int/90, dtype: float64
#
# 📌 Column: Sprints/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         4.751517
# std          5.129998
# min          0.000000
# 25%          0.000000
# 50%          3.860000
# 75%          8.990000
# max         28.620000
# Name: Sprints/90, dtype: float64
#
# 📌 Column: Hdrs W/90
# Type: float64
# Missing: 7798 / 19558
# count    11760.000000
# mean         2.471461
# std          1.824944
# min          0.000000
# 25%          1.070000
# 50%          2.000000
# 75%          3.670000
# max          8.860000
# Name: Hdrs W/90, dtype: float64
#
# 📌 Column: Gls/90
# Type: float64
# Missing: 8098 / 19558
# count    11460.00000
# mean         0.16958
# std          0.14866
# min          0.02000
# 25%          0.06000
# 50%          0.11000
# 75%          0.23000
# max          1.10000
# Name: Gls/90, dtype: float64
#
# 📌 Column: All/90
# Type: float64
# Missing: 17509 / 19558
# count    2049.000000
# mean        1.269829
# std         0.369767
# min         0.000000
# 25%         1.030000
# 50%         1.250000
# 75%         1.500000
# max         3.010000
# Name: All/90, dtype: float64
#
# 📌 Column: xA/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.081790
# std          0.077764
# min          0.000000
# 25%          0.020000
# 50%          0.070000
# 75%          0.110000
# max          0.760000
# Name: xA/90, dtype: float64
#
# 📌 Column: xG/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.122118
# std          0.117438
# min          0.000000
# 25%          0.030000
# 50%          0.080000
# 75%          0.190000
# max          1.020000
# Name: xG/90, dtype: float64
#
# 📌 Column: xGP/90
# Type: float64
# Missing: 17509 / 19558
# count    2049.000000
# mean        0.037086
# std         0.194879
# min        -1.050000
# 25%         0.000000
# 50%         0.000000
# 75%         0.090000
# max         0.890000
# Name: xGP/90, dtype: float64
#
# 📌 Column: Drb/90
# Type: float64
# Missing: 8923 / 19558
# count    10635.000000
# mean         0.972506
# std          0.841397
# min          0.020000
# 25%          0.320000
# 50%          0.760000
# 75%          1.340000
# max          5.310000
# Name: Drb/90, dtype: float64
#
# 📌 Column: Dist/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         3.943604
# std          3.456740
# min          0.000000
# 25%          0.000000
# 50%          5.100000
# 75%          7.300000
# max          9.100000
# Name: Dist/90, dtype: float64
#
# 📌 Column: Cr C/90
# Type: float64
# Missing: 2049 / 19558
# count    17509.000000
# mean         0.185316
# std          0.320673
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.230000
# max          4.300000
# Name: Cr C/90, dtype: float64
#
# 📌 Column: Cln/90
# Type: float64
# Missing: 17509 / 19558
# count    2049.000000
# mean        0.273450
# std         0.149976
# min         0.000000
# 25%         0.160000
# 50%         0.260000
# 75%         0.370000
# max         1.040000
# Name: Cln/90, dtype: float64
#
# 📌 Column: Ch C/90
# Type: float64
# Missing: 10370 / 19558
# count    9188.000000
# mean        0.215617
# std         0.164824
# min         0.020000
# 25%         0.090000
# 50%         0.170000
# 75%         0.290000
# max         1.940000
# Name: Ch C/90, dtype: float64
#
# 📌 Column: Cons
# Type: float64
# Missing: 19558 / 19558
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Cons, dtype: float64
#
# 📌 Column: Pas A
# Type: int64
# Missing: 0 / 19558
# count    19558.000000
# mean       570.041722
# std        302.908582
# min        188.000000
# 25%        360.000000
# 50%        460.000000
# 75%        712.000000
# max       3589.000000
# Name: Pas A, dtype: float64
#
# 📌 Column: Inf
# Type: object
# Missing: 10593 / 19558
# Unique Values: 23
# Sample: ['Wnt' 'Inj' 'nEU' 'Ama' 'Yth' 'Unh' 'Ctr' 'Opt' 'Ask' 'Lst']
#
# 📌 Column: Pas %
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean        75.623172
# std         11.575441
# min         36.000000
# 25%         67.000000
# 50%         80.000000
# 75%         86.000000
# max         96.000000
# Name: Pas %, dtype: float64
#
# 📌 Column: Blk/90
# Type: float64
# Missing: 8767 / 19558
# count    10791.000000
# mean         0.399556
# std          0.238046
# min          0.020000
# 25%          0.220000
# 50%          0.370000
# 75%          0.540000
# max          1.670000
# Name: Blk/90, dtype: float64
#
# 📌 Column: Aer A/90
# Type: float64
# Missing: 7798 / 19558
# count    11760.000000
# mean         5.452401
# std          2.837328
# min          0.030000
# 25%          3.697500
# 50%          5.435000
# 75%          7.310000
# max         16.270000
# Name: Aer A/90, dtype: float64
#
# 📌 Column: Asts/90
# Type: float64
# Missing: 6344 / 19558
# count    13214.000000
# mean         0.140477
# std          0.095326
# min          0.020000
# 25%          0.070000
# 50%          0.110000
# 75%          0.180000
# max          1.010000
# Name: Asts/90, dtype: float64
#
# 📌 Column: Crs A/90
# Type: float64
# Missing: 2049 / 19558
# count    17509.000000
# mean         1.252756
# std          2.043974
# min          0.000000
# 25%          0.000000
# 50%          0.260000
# 75%          1.640000
# max         22.610000
# Name: Crs A/90, dtype: float64
#
# 📌 Column: Hdrs L/90
# Type: float64
# Missing: 7863 / 19558
# count    11695.000000
# mean         2.997550
# std          2.027258
# min          0.030000
# 25%          1.850000
# 50%          2.570000
# 75%          3.680000
# max         11.500000
# Name: Hdrs L/90, dtype: float64
#
# 📌 Column: Division
# Type: object
# Missing: 0 / 19558
# Unique Values: 757
# Sample: ['Premier League' 'Yelo League' 'Serie BKT' 'SuperLiga'
#  'cinch Premiership' 'cinch League One' 'Liga BetPlay Dimayor'
#  'Ligue Professionnelle 1 Mobilis' 'Fortuna liga' 'Primera Nacional']
#
# 📌 Column: Nat
# Type: object
# Missing: 0 / 19558
# Unique Values: 191
# Sample: ['FRA' 'ISR' 'SRB' 'ROU' 'SCO' 'COL' 'POL' 'ALG' 'CZE' 'ARG']
#
# 📌 Column: Fls
# Type: int64
# Missing: 0 / 19558
# count    19558.000000
# mean        18.202781
# std         11.196840
# min          0.000000
# 25%         11.000000
# 50%         17.000000
# 75%         24.000000
# max        116.000000
# Name: Fls, dtype: float64
#
# 📌 Column: xG/shot
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.100541
# std          0.055731
# min          0.000000
# 25%          0.080000
# 50%          0.100000
# 75%          0.130000
# max          1.040000
# Name: xG/shot, dtype: float64
#
# 📌 Column: FK Shots
# Type: float64
# Missing: 2049 / 19558
# count    17509.000000
# mean         0.061797
# std          0.405098
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          8.000000
# Name: FK Shots, dtype: float64
#
# 📌 Column: Goals Outside Box
# Type: float64
# Missing: 2049 / 19558
# count    17509.000000
# mean         0.158090
# std          0.504062
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          7.000000
# Name: Goals Outside Box, dtype: float64
#
# 📌 Column: Tck R
# Type: float64
# Missing: 1222 / 19558
# count    18336.000000
# mean        78.721313
# std         18.365783
# min          0.000000
# 25%         73.000000
# 50%         82.000000
# 75%         90.000000
# max        100.000000
# Name: Tck R, dtype: float64
#
# 📌 Column: xG-OP
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean        -0.441306
# std          1.981919
# min        -11.950000
# 25%         -1.280000
# 50%         -0.270000
# 75%          0.350000
# max         19.370000
# Name: xG-OP, dtype: float64
#
# 📌 Column: Pens Saved Ratio
# Type: float64
# Missing: 18731 / 19558
# count    827.000000
# mean      24.215236
# std       34.958981
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       50.000000
# max      100.000000
# Name: Pens Saved Ratio, dtype: float64
#
# 📌 Column: Pen/R
# Type: float64
# Missing: 18667 / 19558
# count    891.000000
# mean      81.782267
# std       34.870930
# min        0.000000
# 25%      100.000000
# 50%      100.000000
# 75%      100.000000
# max      100.000000
# Name: Pen/R, dtype: float64
#
# 📌 Column: Yel
# Type: int64
# Missing: 0 / 19558
# count    19558.000000
# mean         1.358677
# std          1.979143
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          2.000000
# max         19.000000
# Name: Yel, dtype: float64
#
# 📌 Column: Red
# Type: int64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.216842
# std          0.562655
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         10.000000
# Name: Red, dtype: float64
#
# 📌 Column: Expires
# Type: string
# Missing: 19558 / 19558
# Sample: []
#
# 📌 Column: Signability
# Type: object
# Missing: 0 / 19558
# Unique Values: 3
# Sample: ['Available for Transfer' 'Available on Loan' 'Not Transferrable']
#
# 📌 Column: League Multiplier
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.319609
# std          0.285233
# min          0.050000
# 25%          0.050000
# 50%          0.300000
# 75%          0.500000
# max          0.957000
# Name: League Multiplier, dtype: float64
#
# 📌 Column: Yellow/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.076989
# std          0.108596
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.125000
# max          0.773810
# Name: Yellow/90, dtype: float64
#
# 📌 Column: Red/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.011819
# std          0.030668
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.416667
# Name: Red/90, dtype: float64
#
# 📌 Column: FoulsMade/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         1.002134
# std          0.512922
# min          0.000000
# 25%          0.698642
# 50%          1.032931
# 75%          1.347808
# max          3.138549
# Name: FoulsMade/90, dtype: float64
#
# 📌 Column: FoulsAgainst/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.919241
# std          0.634409
# min          0.000000
# 25%          0.461285
# 50%          0.811320
# 75%          1.213055
# max          5.525800
# Name: FoulsAgainst/90, dtype: float64
#
# 📌 Column: Offsides/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.089536
# std          0.174940
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.089888
# max          1.925134
# Name: Offsides/90, dtype: float64
#
# 📌 Column: Gl Mst/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.002257
# std          0.013174
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.297275
# Name: Gl Mst/90, dtype: float64
#
# 📌 Column: Goals Outside Box/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.008122
# std          0.027385
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.426945
# Name: Goals Outside Box/90, dtype: float64
#
# 📌 Column: FKShots/90
# Type: float64
# Missing: 0 / 19558
# count    19558.000000
# mean         0.003307
# std          0.023940
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.653358
# Name: FKShots/90, dtype: float64

# %%
if df['Dist/90'].isna().any():
    print("⚠️ Warning: Missing or zero values found in Dist/90")

# %%
# ================================
# DATA PREPROCESSING
# ================================
if 'Mins' in df.columns:
    df['Mins'] = pd.to_numeric(df['Mins'], errors='coerce')
    df = df[df['Mins'] >= 900].copy()

# Create composite metrics before scaling
df['Intensity'] = df["Sprints/90"] / df["Dist/90"].replace(0, 1)  # Avoid division by zero
df['NetPoss'] = df["Poss Won/90"] - df["Poss Lost/90"]
# For attacking players:
df['ChanceCreation'] = 0.20 * df['Ch C/90'] + 0.80* df['xA/90']
# For defenders:
df['AerialDominance'] = (df['Hdrs W/90'] * df['Hdr %']) / 100

# Define numeric columns to scale (excluding text columns and Signability)
TEXT_COLUMNS = ['EU National', 'Name', 'UID', 'Position', 'Personality', 'Preferred Foot', 
                'Rec', 'Club', 'Transfer Value', 'Division', 'Nat', 'Inf', 'Signability','Expires']
                
numeric_columns = [col for col in df.columns 
                   if col not in TEXT_COLUMNS 
                   and pd.api.types.is_numeric_dtype(df[col])]

# Scale numeric columns (0-1)
for col in numeric_columns:
    if col == 'Age':
        continue  # Skip scaling for Age column
    if df[col].nunique() > 1:  # Only scale if there's variation
        min_val = df[col].min()
        max_val = df[col].max()
        df[col] = (df[col] - min_val) / (max_val - min_val)
    else:
        df[col] = 0.5  # Default value for constant columns

# Add league multiplier (no scaling needed)
def get_league_multiplier(division):
    return LEAGUE_POWER.get(division, LEAGUE_POWER['Others']) / 100.0

df['League Multiplier'] = df['Division'].apply(get_league_multiplier)

# ================================
# UPDATED ARCHETYPE FORMULAS (SCALED)
# ================================
ARCHETYPE_FORMULAS = {
    "Sweeper Keeper": {
        "filter": df['Position'].str.contains("GK", case=False, na=False),
        "formula": lambda d: (
            0.80 * d["xGP/90"] +
            0.15 * d["Pas %"] +
            0.05 * (1 - d["Gl Mst/90"])
        ),
        "label": "SK Rating"
    },
    
    "Central Defender": {
        "filter": df['Position'].str.contains(r"^D\s*\(([RLC]*C[RLC]*)\)", regex=True, na=False),
        "formula": lambda d: (
            0.80 * ((d["Clr/90"] + d["Int/90"] + d["Blk/90"] + 
                    d["Shts Blckd/90"] + d["AerialDominance"] + 
                    d["K Tck/90"] + d["Tck/90"]) / 7) +  # Average of 7 metrics
            0.05 * (1 - d["Gl Mst/90"]) +
            0.15 * d["Pas %"]
        ),
        "label": "CD Rating"
    },
    
    "Fullback": {
        "filter": df['Position'].str.contains(r"^(D)\s*\((R|L|RL|RLC)\)", regex=True, na=False),
        "formula": lambda d: (
            0.80 * d["xA/90"] +
            0.05 * (d["Pr passes/90"] + d["Drb/90"]) / 2 + 
            0.15 * d["Intensity"]
        ),
        "label": "FB Rating"
    },
    
    "Defensive Midfielder": {
        "filter": df['Position'].str.contains(r"DM", regex=True, na=False),
        "formula": lambda d: (
            0.80 * ((d["Clr/90"] + d["Int/90"] + d["Blk/90"] + 
                    d["Shts Blckd/90"] + d["AerialDominance"] + 
                    d["K Tck/90"] + d["Tck/90"]) / 7) +  # Average of 7 metrics
            0.15 * d["Pas %"] +
            0.05 * d["Pr passes/90"]

        ),
        "label": "DM Rating"
    },

        "Attacking Midfielder": {
        "filter": df['Position'].str.contains(r"^AM\s*\((C|RC|LC|RLC)\)", regex=True, na=False),
        "formula": lambda d: (
            0.80 * (d["NP-xG/90"] + d["xA/90"]) /2 +
            0.15 * d["Pas %"] +
            0.05 * d["Drb/90"]
        ),
        "label": "AM Rating"
    },
    
    "Winger": {
        "filter": df['Position'].str.contains(r"^AM\s*\((L|R|RL|RLC)\)", regex=True, na=False),
        "formula": lambda d: (
            0.80 * (d["NP-xG/90"] + d["xA/90"]) /2 +
            0.10 * d["Drb/90"] +
            0.10 * d["Pres C/90"]
            
        ),
        "label": "W Rating"
    },

    
    "Striker AF": {
        "filter": df['Position'].str.contains(r"ST", regex=True, na=False),
        "formula": lambda d: (
            0.80 * d["NP-xG/90"] +
            0.10 * (1- d["Offsides/90"]) +
            0.10 * d["Intensity"]
        ),
        "label": "ST AF Rating"
    }
}



# ================================
# OUTPUT TO EXCEL WITH SUMMARY SHEET
# ================================
output_excel = BytesIO()

with pd.ExcelWriter(output_excel, engine='xlsxwriter', engine_kwargs={'options': {'strings_to_urls': False}}) as writer:
    workbook = writer.book
    unicode_format = workbook.add_format({'font_name': 'Arial Unicode MS', 'valign': 'vcenter'})
    
    # First create the summary sheet at the beginning
    worksheet = workbook.add_worksheet('Player Archetype Summary')
    writer.sheets['Player Archetype Summary'] = worksheet
    
    # Dictionary to store archetype data for summary
    summary_data = []
    
    # Process all archetypes
    for role, config in ARCHETYPE_FORMULAS.items():
        role_df = df[config["filter"]].copy()
        if role_df.empty:
            continue

        # Calculate ratings
        role_df[config["label"]] = config["formula"](role_df)
        adjusted_label = f"Adjusted {config['label']}"
        role_df[adjusted_label] = role_df[config["label"]] * role_df['League Multiplier']
        
        # Calculate percentile for each player within this archetype
        role_df['Percentile'] = role_df[adjusted_label].rank(pct=True)
        
        # Store data for summary
        top_players = role_df[role_df['Percentile'] > 0.95][['UID', 'Name', 'Percentile']].copy()
        top_players['Archetype'] = role
        summary_data.append(top_players)
        
        # Write archetype sheet
        role_df['Ranking'] = role_df[adjusted_label].rank(method='min', ascending=False)
        
        output_cols = [
            'UID', 'Name', 'Age', 'Personality', 'Signability', 'EU National', 'Position', 'Preferred Foot',
            'Transfer Value', 'Nat', 'Division', 'Club',
            config["label"], adjusted_label, 'Percentile', 'Ranking', 'League Multiplier', 'Expires'
        ]
        
        result_df = role_df[output_cols].copy().sort_values(by=adjusted_label, ascending=False)
        result_df.to_excel(writer, sheet_name=role, index=False)
        
        # Format archetype sheet
        archetype_sheet = writer.sheets[role]
        for i, col in enumerate(output_cols):
            archetype_sheet.set_column(i, i, 20 if col != 'Name' else 30, unicode_format)
        
        # Format percentile as percentage
        percent_format = workbook.add_format({'num_format': '0.0%'})
        percentile_col_idx = output_cols.index('Percentile')
        archetype_sheet.set_column(percentile_col_idx, percentile_col_idx, 12, percent_format)
    
    # ================================
    # BUILD SUMMARY SHEET DATA
    # ================================
    if summary_data:
        all_archetypes = pd.concat(summary_data).sort_values(['UID', 'Percentile'], ascending=[True, False])
        
        # Group and format archetypes
        def format_archetypes(group):
            return ", ".join(f"{row['Archetype']} ({row['Percentile']:.1%})" for _, row in group.iterrows())
        
        player_summary = (
            all_archetypes.groupby(['UID', 'Name'])
            .apply(format_archetypes)
            .reset_index(name='Top Archetypes (>95%)')
        )
        
        # Add additional info
        player_summary = player_summary.merge(
            df[['UID', 'Position', 'Age', 'Nat', 'Club', 'Division', 'Personality', 'Signability', 'Transfer Value']],
            on='UID', how='left'
        )
        
        # Final columns and sorting
        player_summary = player_summary[[
            'UID', 'Name', 'Position', 'Club', 'Division', 
            'Signability', 'Transfer Value', 'Age', 'Nat', 'Personality', 'Top Archetypes (>95%)'
        ]]
        player_summary['Archetype Count'] = player_summary['Top Archetypes (>95%)'].str.count(',') + 1
        player_summary = player_summary.sort_values(['Archetype Count', 'Name'], ascending=[False, True])
        
        # Write to summary sheet
        player_summary.to_excel(writer, sheet_name='Player Archetype Summary', index=False)
        
        # Format summary sheet
        summary_sheet = writer.sheets['Player Archetype Summary']
        summary_sheet.set_column('A:A', 15)  # UID
        summary_sheet.set_column('B:B', 30)  # Name
        summary_sheet.set_column('C:C', 15)  # Position
        summary_sheet.set_column('D:D', 25)  # Club
        summary_sheet.set_column('E:E', 25)  # Division
        summary_sheet.set_column('F:F', 15)  # Signability
        summary_sheet.set_column('G:G', 15)  # Transfer Value
        summary_sheet.set_column('H:H', 60)  # Age
        summary_sheet.set_column('I:I', 60)  # Nationality
        summary_sheet.set_column('J:J', 60)  # Personality
        summary_sheet.set_column('K:K', 60)  # Top Archetypes

# ================================
# SAVE FILE
# ================================
try:
    with open(OUTPUT_PATH, 'wb') as output_file:
        output_file.write(output_excel.getbuffer())
    print(f"\n✅ Success! Output file saved:\n{OUTPUT_PATH}")
    print(f"Includes {len(ARCHETYPE_FORMULAS)} archetype sheets + summary sheet")
except Exception as e:
    print(f"\n❌ Error saving file: {e}")
    print("Please check directory permissions or disk space.")
# Out:
# C:\Users\Testing Rename nalng\AppData\Local\Temp\ipykernel_248\4269282769.py:194: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(format_archetypes)
# ✅ Success! Output file saved:
# C:/Users/Testing Rename nalng/Desktop/Stuttgart_Season_1_Winter_FB_Fix.xlsx
# Includes 7 archetype sheets + summary sheet

# %%
# Test each archetype with dummy perfect player
test_player = {col: 1 for col in numeric_columns}
for name, archetype in ARCHETYPE_FORMULAS.items():
    print(f"{name}: {archetype['formula'](test_player)}")
# Out:
# Sweeper Keeper: 0.9500000000000001
# Central Defender: 0.9500000000000001
# Fullback: 1.0
# Defensive Midfielder: 1.0
# Attacking Midfielder: 1.0
# Winger: 1.0
# Striker AF: 0.9
